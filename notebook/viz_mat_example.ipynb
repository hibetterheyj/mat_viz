# %%
import os
import scipy
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

from utils import plot_variables, plot_axay, plot_wz, plot_bat_tem_max

# %%
data_dir = Path('../test_data/')
os.listdir(data_dir)
# Out:
# ['dre16_2017-05-07_16-25-34.mat',
#  'dre16_2017-08-04_17-45-26.mat',
#  'dre16_2017-08-04_17-56-00.mat']

# %%
mat_data1 = sio.loadmat(data_dir / 'dre16_2017-05-07_16-25-34.mat')

# %% [markdown]
# ## general function & examples

# %%
vars = ['dbc_Dr_00_CCFb_03_ax_02', 'dbc_Dr_00_CCFb_03_ay_03']
plot_variables(
    mat_data = mat_data1, 
    vars=vars, 
    xlims=[35,90],
    title = 'Acc changesb alone the time',
    ylabel = 'Accleration ($m/s^2$)',
)

# %% [markdown]
# ## specfic functions & emxamples

# %%
plot_axay(mat_data1)

# %%
plot_wz(mat_data1)

# %%
plot_bat_tem_max(mat_data1)
